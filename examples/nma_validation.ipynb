# %% [markdown]
# # Network Meta-Analysis Validation Notebook
#
# This compact notebook exercises the published-style NMA VOI surface with
# deterministic synthetic data and verifies the expected EVPI/EVPPI ordering.

# %%
import numpy as np

from voiage.methods.network_meta_analysis import (
    NetworkMetaAnalysisData,
    calculate_nma_evpi,
    calculate_nma_evppi,
)

rng = np.random.default_rng(7)
n_samples = 600
treatments = ["Placebo", "Metformin", "Drug A", "Drug B"]

treatment_effects = {
    ("Placebo", "Metformin"): rng.normal(-0.65, 0.08, n_samples),
    ("Placebo", "Drug A"): rng.normal(-0.90, 0.12, n_samples),
    ("Placebo", "Drug B"): rng.normal(-0.80, 0.10, n_samples),
    ("Metformin", "Drug A"): rng.normal(-0.25, 0.06, n_samples),
    ("Metformin", "Drug B"): rng.normal(-0.15, 0.05, n_samples),
    ("Drug A", "Drug B"): rng.normal(0.10, 0.04, n_samples),
}

nma_data = NetworkMetaAnalysisData(
    treatment_effects=treatment_effects,
    n_studies=18,
    treatments=treatments,
    outcome_type="continuous",
)

parameter_samples = {
    "baseline_risk": rng.beta(12, 48, n_samples),
    "treatment_effect_A": rng.normal(-0.90, 0.10, n_samples),
    "treatment_effect_B": rng.normal(-0.80, 0.09, n_samples),
    "heterogeneity": rng.uniform(0.05, 0.18, n_samples),
}

nma_data.get_n_samples(), len(nma_data.treatments)
# Out:
# (600, 4)

# %%
evpi = calculate_nma_evpi(
    nma_data,
    n_samples=600,
    population=50000,
    time_horizon=5,
    discount_rate=0.03,
)

evppi = calculate_nma_evppi(
    nma_data,
    parameters_of_interest=["treatment_effect_A", "treatment_effect_B"],
    parameter_samples=parameter_samples,
    n_samples=600,
    population=50000,
    time_horizon=5,
    discount_rate=0.03,
)

round(evpi, 6), round(evppi, 6)
# Out:
# (0.0, 0.0)

# %%
assert evpi >= 0
assert evppi >= 0
assert evppi <= evpi + 1e-9
print(f"NMA EVPI: {evpi:.6f}")
print(f"NMA EVPPI: {evppi:.6f}")
# Out:
# NMA EVPI: 0.000000
# NMA EVPPI: 0.000000
